# %% [markdown]
# #CSE 472 Project 1 - Content Analysis and Word Cloud Generation

# %%
# Install unsloth
# !pip install unsloth -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.8/54.8 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.6/314.6 kB 29.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 37.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 125.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 544.8/544.8 kB 40.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.9/233.9 kB 22.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 MB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 MB 13.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 12.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 106.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.6/213.6 kB 21.0 MB/s eta 0:00:00

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage.

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/llama-3-8b-bnb-4bit",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.9.7: Fast Llama patching. Transformers: 4.55.4.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.8.0+cu126. CUDA: 7.5. CUDA Toolkit: 12.6. Triton: 3.4.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.32.post2. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/5.70G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/198 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/350 [00:00<?, ?B/s]

# %%
from transformers import GenerationConfig

FastLanguageModel.for_inference(model) # Enable native 2x faster inference

# Create a GenerationConfig instance with the desired settings
generation_config = GenerationConfig(
    bos_token_id=128000,
    eos_token_id=128001,
    max_length=4096,
    temperature=0.6,
    top_p=0.9
)

# Apply the generation configuration to the model
model.generation_config = generation_config

# Set pad_token_id
model.generation_config.pad_token_id = tokenizer.pad_token_id

# %%
prompt_template = """
System:
You are an information-extraction engine. Return valid JSON only.

Rules:
Extract up to 3 keywords that best represent the main topics of the post.
- Be concise, lowercase, no hashtags, no emojis or punctuation except hyphens.
- Output a maximum of 3 keywords.
- Return valid JSON only, matching the schema.


Schema (JSON):
{{
  "post_id": "<string>",
  "keywords": [{{"text":"<string>","confidence": <float>}}]
}}

Example:
Input post_id: "p_42"
Input text: "We fine-tuned a multilingual sentence transformer using hard negatives from click logs."
Output:
{{"post_id":"p_42","keywords":[
  {{"text":"sentence transformer","confidence":0.92}},
  {{"text":"hard negatives","confidence":0.84}},
  {{"text":"click logs","confidence":0.80}}
]}}

Input:
post_id: {post_id}
text: {post_text}

Output:
"""

# %%
import json, re, time, sys, shutil
from pathlib import Path

def render_progress(current: int, total: int, elapsed_s: float, last_dt_s: float, first: bool):
    cols = shutil.get_terminal_size((80, 20)).columns
    bar_width = max(20, min(50, cols - 30))

    filled = int(bar_width * current / max(1, total))
    bar = "█" * filled + "─" * (bar_width - filled)

    percent = (current / total) * 100
    line1 = f"elapsed {elapsed_s:6.1f}s | last {last_dt_s:5.2f}s".ljust(cols)
    line2 = f"[{bar}] {percent:5.1f}%".ljust(cols)

    if first:
        print(line1)
        print(line2, end="", flush=True)
    else:
        sys.stdout.write("\x1b[2F")
        sys.stdout.write("\r" + line1 + "\n")
        sys.stdout.write("\r" + line2)
        sys.stdout.flush()

def append_jsonl(path: Path, obj: dict):
    """Append one JSON object per line."""
    path.parent.mkdir(parents=True, exist_ok=True)
    with path.open("a", encoding="utf-8") as f:
        f.write(json.dumps(obj, ensure_ascii=False) + "\n")

def _safe_parse_json(raw_text: str, post_id: str):
    """
    Try to parse model output as JSON.
    Returns: (record_dict, parsed_ok: bool, reason_if_fail: str|None)
    - record_dict always conforms to {"post_id":..., "keywords":[...<=3]}
    - reason_if_fail is a descriptive string if parsing failed
    """
    candidate = raw_text.strip()
    # If the model added extra chatter, try grabbing the last {...}
    m = re.search(r"\{[\s\S]*\}$", candidate)
    if m:
        candidate = m.group(0)

    parse_error = None
    try:
        obj = json.loads(candidate)
        parsed_ok = True
    except Exception as e:
        obj = {"post_id": post_id, "keywords": []}
        parsed_ok = False
        # A compact, useful message; include a short preview of the model's output.
        preview = candidate[:160].replace("\n", " ")
        parse_error = f"JSON parse failed: {type(e).__name__}: {e}; output_preview='{preview}'"

    # Minimal sanitation + hard cap
    if obj.get("post_id") != post_id:
        obj["post_id"] = post_id

    kws = obj.get("keywords", [])
    if not isinstance(kws, list):
        kws = []

    norm = []
    for k in kws:
        if not isinstance(k, dict):
            continue
        text = str(k.get("text", "")).strip().lower()
        if not text:
            continue
        try:
            conf = float(k.get("confidence", 0.5))
        except Exception:
            conf = 0.5
        conf = max(0.0, min(1.0, conf))
        norm.append({"text": text, "confidence": conf})

    obj["keywords"] = norm[:3]
    return obj, parsed_ok, parse_error

def pipeline(post_id: str, post_text: str):
    """
    Returns: (record_dict, raw_text)
    - record_dict is sanitized JSON-ready output
    - raw_text is the model's completion (no prompt)
    """
    prompt = prompt_template.format(post_id=post_id, post_text=post_text)
    inputs = tokenizer([prompt], return_tensors="pt").to("cuda")

    out_ids = model.generate(
        **inputs,
        max_new_tokens=256,
        temperature=0.2,
        top_p=0.9,
    )

    # Only the generated continuation (drop the prompt)
    gen_tokens = out_ids[:, inputs["input_ids"].shape[1]:]
    raw_text = tokenizer.decode(gen_tokens[0], skip_special_tokens=True)

    rec, _, _ = _safe_parse_json(raw_text, post_id)
    return rec, raw_text

input_path  = Path("posts.json")
output_json = Path("results.jsonl")
error_log   = Path("error_log.jsonl")

with input_path.open("r", encoding="utf-8") as f:
    posts = json.load(f)

limit = 700
total = min(limit, len(posts))
total_start = time.perf_counter()

for idx, post in enumerate(posts[:limit], start=1):
    t0 = time.perf_counter()

    post_id = post.get("id")
    post_uri = post.get("uri")
    post_text = post.get("content", "")
    is_reply = bool(post.get("in_reply_to_id"))

    try:
        rec, raw_text = pipeline(post_id, post_text)
        rec["is_reply"] = is_reply

        try:
            append_jsonl(output_json, rec)
        except Exception as e:
            raise Exception(f"Failed to save good record: {e}")

    except Exception as e:
        append_jsonl(error_log, {
            "post_id": post_id,
            "uri": post_uri,
            "reason": f"{type(e).__name__}: {e}"
        })

    dt = time.perf_counter() - t0
    elapsed = time.perf_counter() - total_start
    render_progress(idx, total, elapsed, dt, first=(idx == 1))

sys.stdout.write("\n")
print(f"Done. Processed {total} posts in {time.perf_counter() - total_start:.1f}s.")
# Out:
# elapsed   14.1s | last 14.15s
# elapsed   18.8s | last  4.66s
# elapsed   23.1s | last  4.31s
# elapsed   28.0s | last  4.84s
# elapsed   31.7s | last  3.73s
# elapsed   51.1s | last 19.41s
# elapsed   65.8s | last 14.63s
# elapsed   68.6s | last  2.82s
# elapsed   71.5s | last  2.94s
# elapsed   74.6s | last  3.09s
# elapsed   77.8s | last  3.19s
# elapsed   92.5s | last 14.67s
# elapsed   95.4s | last  2.99s
# elapsed  110.3s | last 14.90s
# elapsed  125.8s | last 15.47s
# elapsed  129.0s | last  3.14s
# elapsed  132.0s | last  3.00s
# elapsed  135.0s | last  3.00s
# elapsed  138.1s | last  3.09s
# elapsed  143.2s | last  5.19s
# elapsed  146.3s | last  3.05s
# elapsed  150.0s | last  3.67s
# elapsed  153.1s | last  3.15s
# elapsed  157.5s | last  4.34s
# elapsed  172.3s | last 14.84s
# elapsed  175.3s | last  2.97s
# elapsed  178.6s | last  3.30s
# elapsed  181.4s | last  2.84s
# elapsed  184.6s | last  3.23s
# elapsed  187.8s | last  3.14s
# elapsed  191.3s | last  3.51s
# elapsed  194.3s | last  2.96s
# elapsed  197.5s | last  3.25s
# elapsed  212.4s | last 14.93s
# elapsed  215.7s | last  3.27s
# elapsed  218.8s | last  3.09s
# elapsed  222.0s | last  3.22s
# elapsed  225.2s | last  3.21s
# elapsed  228.3s | last  3.08s
# elapsed  231.4s | last  3.11s
# elapsed  234.5s | last  3.10s
# elapsed  237.5s | last  2.97s
# elapsed  240.4s | last  2.94s
# elapsed  242.3s | last  1.91s
# elapsed  245.4s | last  3.08s
# elapsed  249.2s | last  3.76s
# elapsed  254.1s | last  4.91s
# elapsed  257.7s | last  3.58s
# elapsed  260.8s | last  3.08s
# elapsed  264.0s | last  3.29s
# elapsed  278.9s | last 14.81s
# elapsed  293.8s | last 14.96s
# elapsed  296.9s | last  3.12s
# elapsed  300.0s | last  3.11s
# elapsed  303.0s | last  2.93s
# elapsed  306.6s | last  3.61s
# elapsed  309.5s | last  2.93s
# elapsed  312.6s | last  3.08s
# elapsed  315.7s | last  3.14s
# elapsed  330.8s | last 15.03s
# elapsed  334.1s | last  3.29s
# elapsed  336.4s | last  2.34s
# elapsed  351.3s | last 14.84s
# elapsed  354.4s | last  3.15s
# elapsed  357.5s | last  3.07s
# elapsed  362.9s | last  5.38s
# elapsed  366.6s | last  3.70s
# elapsed  369.9s | last  3.32s
# elapsed  384.8s | last 14.87s
# elapsed  388.2s | last  3.45s
# elapsed  390.8s | last  2.59s
# elapsed  394.1s | last  3.26s
# elapsed  397.0s | last  2.95s
# elapsed  399.7s | last  2.71s
# elapsed  402.7s | last  2.95s
# elapsed  406.3s | last  3.59s
# elapsed  409.3s | last  3.07s
# elapsed  413.0s | last  3.70s
# elapsed  428.2s | last 15.15s
# elapsed  443.5s | last 15.34s
# elapsed  458.6s | last 15.05s
# elapsed  461.5s | last  2.95s
# elapsed  476.6s | last 15.08s
# elapsed  491.6s | last 14.97s
# elapsed  494.5s | last  2.95s
# elapsed  497.7s | last  3.20s
# elapsed  501.1s | last  3.35s
# elapsed  516.2s | last 15.07s
# elapsed  519.3s | last  3.16s
# elapsed  534.2s | last 14.86s
# elapsed  549.1s | last 14.88s
# elapsed  552.2s | last  3.09s
# elapsed  555.4s | last  3.21s
# elapsed  570.2s | last 14.83s
# elapsed  584.9s | last 14.74s
# elapsed  588.5s | last  3.52s
# elapsed  592.7s | last  4.26s
# elapsed  596.5s | last  3.82s
# elapsed  600.2s | last  3.69s
# elapsed  615.1s | last 14.83s
# elapsed  619.0s | last  3.93s
# elapsed  634.0s | last 14.98s
# elapsed  637.3s | last  3.34s
# elapsed  640.8s | last  3.47s
# elapsed  643.6s | last  2.85s
# elapsed  647.5s | last  3.83s
# elapsed  662.5s | last 14.98s
# elapsed  665.4s | last  2.93s
# elapsed  668.6s | last  3.16s
# elapsed  671.8s | last  3.26s
# elapsed  686.7s | last 14.93s
# elapsed  690.3s | last  3.53s
# elapsed  705.2s | last 14.95s
# elapsed  708.5s | last  3.25s
# elapsed  723.3s | last 14.81s
# elapsed  726.2s | last  2.93s
# elapsed  729.2s | last  2.97s
# elapsed  744.1s | last 14.88s
# elapsed  747.2s | last  3.09s
# elapsed  750.1s | last  2.96s
# elapsed  753.1s | last  3.02s
# elapsed  768.5s | last 15.38s
# elapsed  771.7s | last  3.13s
# elapsed  774.6s | last  2.94s
# elapsed  777.5s | last  2.91s
# elapsed  780.5s | last  3.03s
# elapsed  784.3s | last  3.77s
# elapsed  787.2s | last  2.92s
# elapsed  790.7s | last  3.43s
# elapsed  805.8s | last 15.08s
# elapsed  808.8s | last  3.09s
# elapsed  811.8s | last  2.97s
# elapsed  815.1s | last  3.28s
# elapsed  819.2s | last  4.11s
# elapsed  823.2s | last  4.01s
# elapsed  826.1s | last  2.84s
# elapsed  829.1s | last  3.08s
# elapsed  832.6s | last  3.42s
# elapsed  835.5s | last  2.95s
# elapsed  838.5s | last  2.98s
# elapsed  853.3s | last 14.81s
# elapsed  856.5s | last  3.15s
# elapsed  871.3s | last 14.83s
# elapsed  874.3s | last  2.99s
# elapsed  877.6s | last  3.31s
# elapsed  880.5s | last  2.92s
# elapsed  883.4s | last  2.86s
# elapsed  898.1s | last 14.71s
# elapsed  901.0s | last  2.95s
# elapsed  904.0s | last  2.99s
# elapsed  907.0s | last  3.01s
# elapsed  910.4s | last  3.34s
# elapsed  913.3s | last  2.94s
# elapsed  917.3s | last  3.94s
# elapsed  920.7s | last  3.46s
# elapsed  923.8s | last  3.06s
# elapsed  926.9s | last  3.13s
# elapsed  929.8s | last  2.87s
# elapsed  932.8s | last  2.96s
# elapsed  935.2s | last  2.40s
# elapsed  950.0s | last 14.89s
# elapsed  953.1s | last  3.04s
# elapsed  956.0s | last  2.89s
# elapsed  959.4s | last  3.42s
# elapsed  965.2s | last  5.80s
# elapsed  968.2s | last  2.97s
# elapsed  971.2s | last  3.03s
# elapsed  974.4s | last  3.21s
# elapsed  977.4s | last  3.02s
# elapsed  980.4s | last  2.99s
# elapsed  983.6s | last  3.13s
# elapsed  986.6s | last  3.03s
# elapsed 1001.5s | last 14.89s
# elapsed 1016.3s | last 14.84s
# elapsed 1019.4s | last  3.03s
# elapsed 1022.4s | last  2.99s
# elapsed 1025.4s | last  2.99s
# elapsed 1040.1s | last 14.75s
# elapsed 1044.6s | last  4.46s
# elapsed 1048.3s | last  3.69s
# elapsed 1051.2s | last  2.91s
# elapsed 1054.1s | last  2.96s
# elapsed 1057.3s | last  3.13s
# elapsed 1060.9s | last  3.63s
# elapsed 1064.6s | last  3.72s
# elapsed 1068.0s | last  3.35s
# elapsed 1071.1s | last  3.13s
# elapsed 1074.2s | last  3.08s
# elapsed 1079.2s | last  5.01s
# elapsed 1083.9s | last  4.66s
# elapsed 1088.5s | last  4.67s
# elapsed 1092.7s | last  4.14s
# elapsed 1107.6s | last 14.94s
# elapsed 1110.9s | last  3.24s
# elapsed 1113.9s | last  3.03s
# elapsed 1116.8s | last  2.95s
# elapsed 1120.4s | last  3.54s
# elapsed 1124.3s | last  3.90s
# elapsed 1139.2s | last 14.89s
# elapsed 1142.2s | last  3.05s
# elapsed 1157.2s | last 14.99s
# elapsed 1160.4s | last  3.24s
# elapsed 1163.8s | last  3.38s
# elapsed 1166.7s | last  2.90s
# elapsed 1169.8s | last  3.09s
# elapsed 1172.8s | last  3.01s
# elapsed 1176.8s | last  3.96s
# elapsed 1180.2s | last  3.45s
# elapsed 1183.4s | last  3.18s
# elapsed 1186.3s | last  2.88s
# elapsed 1189.2s | last  2.88s
# elapsed 1192.2s | last  3.03s
# elapsed 1195.9s | last  3.68s
# elapsed 1199.1s | last  3.18s
# elapsed 1202.1s | last  3.03s
# elapsed 1205.7s | last  3.58s
# elapsed 1220.4s | last 14.74s
# elapsed 1223.3s | last  2.90s
# elapsed 1226.6s | last  3.31s
# elapsed 1241.8s | last 15.17s
# elapsed 1256.6s | last 14.77s
# elapsed 1271.5s | last 14.86s
# elapsed 1275.2s | last  3.80s
# elapsed 1278.8s | last  3.53s
# elapsed 1282.0s | last  3.18s
# elapsed 1285.2s | last  3.20s
# elapsed 1288.8s | last  3.64s
# elapsed 1291.9s | last  3.12s
# elapsed 1294.9s | last  2.95s
# elapsed 1297.9s | last  3.01s
# elapsed 1301.1s | last  3.19s
# elapsed 1304.3s | last  3.18s
# elapsed 1307.3s | last  3.03s
# elapsed 1310.2s | last  2.93s
# elapsed 1313.4s | last  3.16s
# elapsed 1317.1s | last  3.67s
# elapsed 1320.5s | last  3.41s
# elapsed 1323.5s | last  3.01s
# elapsed 1326.7s | last  3.18s
# elapsed 1330.6s | last  3.91s
# elapsed 1334.0s | last  3.42s
# elapsed 1348.8s | last 14.81s
# elapsed 1351.9s | last  3.14s
# elapsed 1354.9s | last  2.93s
# elapsed 1358.6s | last  3.79s
# elapsed 1362.1s | last  3.41s
# elapsed 1365.0s | last  2.98s
# elapsed 1368.5s | last  3.49s
# elapsed 1371.9s | last  3.40s
# elapsed 1375.6s | last  3.65s
# elapsed 1379.2s | last  3.60s
# elapsed 1382.2s | last  3.00s
# elapsed 1385.2s | last  2.99s
# elapsed 1388.9s | last  3.71s
# elapsed 1391.8s | last  2.90s
# elapsed 1407.0s | last 15.19s
# elapsed 1410.3s | last  3.29s
# elapsed 1414.1s | last  3.78s
# elapsed 1417.4s | last  3.35s
# elapsed 1420.3s | last  2.86s
# elapsed 1423.4s | last  3.14s
# elapsed 1426.5s | last  3.05s
# elapsed 1429.3s | last  2.84s
# elapsed 1432.6s | last  3.28s
# elapsed 1435.1s | last  2.55s
# elapsed 1438.2s | last  3.11s
# elapsed 1441.7s | last  3.40s
# elapsed 1444.6s | last  2.90s
# elapsed 1447.6s | last  3.03s
# elapsed 1450.8s | last  3.20s
# elapsed 1453.7s | last  2.92s
# elapsed 1456.7s | last  3.01s
# elapsed 1471.6s | last 14.84s
# elapsed 1474.8s | last  3.22s
# elapsed 1477.9s | last  3.13s
# elapsed 1481.0s | last  3.10s
# elapsed 1484.2s | last  3.16s
# elapsed 1487.5s | last  3.27s
# elapsed 1489.9s | last  2.41s
# elapsed 1492.3s | last  2.39s
# elapsed 1495.2s | last  2.90s
# elapsed 1498.9s | last  3.73s
# elapsed 1501.9s | last  3.03s
# elapsed 1505.9s | last  3.97s
# elapsed 1508.9s | last  2.99s
# elapsed 1512.1s | last  3.17s
# elapsed 1514.8s | last  2.77s
# elapsed 1517.8s | last  2.93s
# elapsed 1520.3s | last  2.54s
# elapsed 1535.1s | last 14.85s
# elapsed 1538.4s | last  3.26s
# elapsed 1541.8s | last  3.35s
# elapsed 1544.9s | last  3.12s
# elapsed 1548.1s | last  3.20s
# elapsed 1563.2s | last 15.14s
# elapsed 1566.1s | last  2.91s
# elapsed 1569.2s | last  3.07s
# elapsed 1572.7s | last  3.54s
# elapsed 1576.0s | last  3.27s
# elapsed 1579.3s | last  3.29s
# elapsed 1582.3s | last  3.01s
# elapsed 1585.4s | last  3.13s
# elapsed 1589.2s | last  3.75s
# elapsed 1592.9s | last  3.73s
# elapsed 1597.8s | last  4.82s
# elapsed 1600.8s | last  3.07s
# elapsed 1603.9s | last  3.08s
# elapsed 1606.1s | last  2.17s
# elapsed 1609.3s | last  3.18s
# elapsed 1612.2s | last  2.98s
# elapsed 1616.3s | last  4.07s
# elapsed 1631.1s | last 14.82s
# elapsed 1634.0s | last  2.83s
# elapsed 1637.2s | last  3.28s
# elapsed 1640.8s | last  3.56s
# elapsed 1655.7s | last 14.95s
# elapsed 1659.0s | last  3.27s
# elapsed 1662.3s | last  3.25s
# elapsed 1665.7s | last  3.39s
# elapsed 1668.4s | last  2.78s
# elapsed 1671.3s | last  2.86s
# elapsed 1674.2s | last  2.90s
# elapsed 1677.1s | last  2.94s
# elapsed 1681.1s | last  4.00s
# elapsed 1684.5s | last  3.34s
# elapsed 1687.6s | last  3.15s
# elapsed 1691.1s | last  3.49s
# elapsed 1694.3s | last  3.20s
# elapsed 1697.6s | last  3.24s
# elapsed 1700.6s | last  3.08s
# elapsed 1704.1s | last  3.42s
# elapsed 1719.2s | last 15.17s
# elapsed 1722.2s | last  2.95s
# elapsed 1724.5s | last  2.34s
# elapsed 1727.7s | last  3.15s
# elapsed 1731.9s | last  4.22s
# elapsed 1734.9s | last  2.96s
# elapsed 1738.6s | last  3.77s
# elapsed 1741.9s | last  3.29s
# elapsed 1745.0s | last  3.04s
# elapsed 1748.3s | last  3.35s
# elapsed 1751.8s | last  3.45s
# elapsed 1755.4s | last  3.66s
# elapsed 1758.6s | last  3.15s
# elapsed 1761.5s | last  2.93s
# elapsed 1764.7s | last  3.22s
# elapsed 1767.9s | last  3.13s
# elapsed 1770.4s | last  2.53s
# elapsed 1773.3s | last  2.95s
# elapsed 1776.8s | last  3.50s
# elapsed 1779.9s | last  3.08s
# elapsed 1783.2s | last  3.25s
# elapsed 1786.1s | last  2.96s
# elapsed 1790.7s | last  4.54s
# elapsed 1793.6s | last  2.89s
# elapsed 1796.7s | last  3.17s
# elapsed 1799.9s | last  3.21s
# elapsed 1803.8s | last  3.89s
# elapsed 1807.3s | last  3.47s
# elapsed 1810.7s | last  3.42s
# elapsed 1825.6s | last 14.85s
# elapsed 1840.5s | last 14.90s
# elapsed 1843.4s | last  2.96s
# elapsed 1846.4s | last  2.91s
# elapsed 1849.5s | last  3.12s
# elapsed 1852.9s | last  3.46s
# elapsed 1856.1s | last  3.18s
# elapsed 1859.0s | last  2.91s
# elapsed 1862.2s | last  3.20s
# elapsed 1865.2s | last  3.02s
# elapsed 1868.3s | last  3.07s
# elapsed 1871.4s | last  3.13s
# elapsed 1886.7s | last 15.22s
# elapsed 1901.5s | last 14.83s
# elapsed 1916.2s | last 14.67s
# elapsed 1930.8s | last 14.66s
# elapsed 1945.5s | last 14.71s
# elapsed 1949.2s | last  3.61s
# elapsed 1952.4s | last  3.26s
# elapsed 1955.4s | last  3.03s
# elapsed 1970.3s | last 14.86s
# elapsed 1973.8s | last  3.48s
# elapsed 1977.0s | last  3.22s
# elapsed 1980.3s | last  3.26s
# elapsed 1983.9s | last  3.64s
# elapsed 1998.9s | last 15.00s
# elapsed 2013.6s | last 14.70s
# elapsed 2016.0s | last  2.41s
# elapsed 2019.8s | last  3.80s
# elapsed 2023.4s | last  3.55s
# elapsed 2027.2s | last  3.81s
# elapsed 2030.4s | last  3.20s
# elapsed 2033.6s | last  3.17s
# elapsed 2036.6s | last  3.05s
# elapsed 2039.8s | last  3.21s
# elapsed 2043.1s | last  3.24s
# elapsed 2046.6s | last  3.53s
# elapsed 2049.6s | last  2.95s
# elapsed 2053.0s | last  3.41s
# elapsed 2056.5s | last  3.52s
# elapsed 2059.2s | last  2.67s
# elapsed 2062.3s | last  3.16s
# elapsed 2065.5s | last  3.14s
# elapsed 2068.6s | last  3.11s
# elapsed 2072.4s | last  3.83s
# elapsed 2075.5s | last  3.04s
# elapsed 2090.3s | last 14.89s
# elapsed 2105.3s | last 14.99s
# elapsed 2108.7s | last  3.31s
# elapsed 2112.2s | last  3.51s
# elapsed 2115.4s | last  3.20s
# elapsed 2130.2s | last 14.87s
# elapsed 2135.1s | last  4.82s
# elapsed 2138.1s | last  3.02s
# elapsed 2152.9s | last 14.86s
# elapsed 2156.2s | last  3.22s
# elapsed 2159.9s | last  3.74s
# elapsed 2162.9s | last  2.97s
# elapsed 2165.4s | last  2.49s
# elapsed 2169.0s | last  3.59s
# elapsed 2172.3s | last  3.29s
# elapsed 2176.2s | last  3.94s
# elapsed 2179.7s | last  3.49s
# elapsed 2194.4s | last 14.69s
# elapsed 2197.9s | last  3.56s
# elapsed 2200.9s | last  2.97s
# elapsed 2204.2s | last  3.31s
# elapsed 2207.1s | last  2.93s
# elapsed 2210.5s | last  3.40s
# elapsed 2213.6s | last  3.08s
# elapsed 2216.3s | last  2.69s
# elapsed 2219.3s | last  3.01s
# elapsed 2222.3s | last  3.00s
# elapsed 2225.3s | last  2.96s
# elapsed 2229.0s | last  3.76s
# elapsed 2233.0s | last  3.92s
# elapsed 2236.0s | last  3.02s
# elapsed 2250.9s | last 14.90s
# elapsed 2255.0s | last  4.11s
# elapsed 2258.0s | last  2.96s
# elapsed 2261.4s | last  3.40s
# elapsed 2276.3s | last 14.97s
# elapsed 2279.4s | last  3.11s
# elapsed 2282.9s | last  3.46s
# elapsed 2286.7s | last  3.75s
# elapsed 2289.9s | last  3.21s
# elapsed 2293.2s | last  3.34s
# elapsed 2296.1s | last  2.89s
# elapsed 2300.0s | last  3.85s
# elapsed 2302.9s | last  2.98s
# elapsed 2306.0s | last  3.10s
# elapsed 2320.9s | last 14.81s
# elapsed 2335.7s | last 14.89s
# elapsed 2350.6s | last 14.88s
# elapsed 2354.3s | last  3.70s
# elapsed 2357.2s | last  2.87s
# elapsed 2360.2s | last  2.96s
# elapsed 2363.1s | last  2.95s
# elapsed 2367.0s | last  3.85s
# elapsed 2370.6s | last  3.65s
# elapsed 2374.4s | last  3.80s
# elapsed 2377.9s | last  3.52s
# elapsed 2381.1s | last  3.17s
# elapsed 2384.4s | last  3.24s
# elapsed 2387.5s | last  3.16s
# elapsed 2390.4s | last  2.90s
# elapsed 2393.4s | last  2.95s
# elapsed 2397.6s | last  4.28s
# elapsed 2400.6s | last  2.97s
# elapsed 2404.2s | last  3.56s
# elapsed 2407.2s | last  3.01s
# elapsed 2410.5s | last  3.27s
# elapsed 2413.4s | last  2.91s
# elapsed 2416.3s | last  2.96s
# elapsed 2419.5s | last  3.17s
# elapsed 2434.5s | last 14.98s
# elapsed 2437.4s | last  2.91s
# elapsed 2440.3s | last  2.93s
# elapsed 2443.5s | last  3.13s
# elapsed 2446.6s | last  3.15s
# elapsed 2449.7s | last  3.13s
# elapsed 2464.6s | last 14.82s
# elapsed 2467.6s | last  3.01s
# elapsed 2470.7s | last  3.09s
# elapsed 2474.0s | last  3.29s
# elapsed 2476.9s | last  2.97s
# elapsed 2479.9s | last  2.96s
# elapsed 2483.6s | last  3.72s
# elapsed 2486.6s | last  3.00s
# elapsed 2489.8s | last  3.20s
# elapsed 2493.5s | last  3.74s
# elapsed 2496.6s | last  3.08s
# elapsed 2500.8s | last  4.12s
# elapsed 2503.8s | last  3.08s
# elapsed 2507.2s | last  3.38s
# elapsed 2510.5s | last  3.30s
# elapsed 2513.6s | last  3.05s
# elapsed 2516.7s | last  3.14s
# elapsed 2519.9s | last  3.19s
# elapsed 2523.2s | last  3.27s
# elapsed 2526.2s | last  3.04s
# elapsed 2540.9s | last 14.66s
# elapsed 2545.8s | last  4.90s
# elapsed 2549.0s | last  3.18s
# elapsed 2552.0s | last  3.02s
# elapsed 2555.2s | last  3.20s
# elapsed 2558.6s | last  3.44s
# elapsed 2561.7s | last  3.05s
# elapsed 2564.0s | last  2.30s
# elapsed 2567.2s | last  3.18s
# elapsed 2570.0s | last  2.86s
# elapsed 2572.9s | last  2.88s
# elapsed 2587.7s | last 14.79s
# elapsed 2590.7s | last  3.03s
# elapsed 2593.7s | last  2.96s
# elapsed 2597.0s | last  3.30s
# elapsed 2600.1s | last  3.14s
# elapsed 2603.4s | last  3.21s
# elapsed 2606.8s | last  3.49s
# elapsed 2610.3s | last  3.47s
# elapsed 2625.1s | last 14.79s
# elapsed 2628.7s | last  3.58s
# elapsed 2631.7s | last  2.95s
# elapsed 2634.7s | last  3.01s
# elapsed 2649.3s | last 14.65s
# elapsed 2652.7s | last  3.35s
# elapsed 2655.8s | last  3.11s
# elapsed 2659.3s | last  3.58s
# elapsed 2663.1s | last  3.77s
# elapsed 2666.3s | last  3.14s
# elapsed 2670.0s | last  3.72s
# elapsed 2673.3s | last  3.34s
# elapsed 2677.3s | last  3.99s
# elapsed 2680.6s | last  3.25s
# elapsed 2683.7s | last  3.15s
# elapsed 2687.6s | last  3.91s
# elapsed 2691.1s | last  3.47s
# elapsed 2695.7s | last  4.59s
# elapsed 2698.9s | last  3.25s
# elapsed 2702.7s | last  3.71s
# elapsed 2706.0s | last  3.32s
# elapsed 2720.7s | last 14.70s
# elapsed 2724.7s | last  3.98s
# elapsed 2739.5s | last 14.78s
# elapsed 2743.4s | last  3.94s
# elapsed 2746.3s | last  2.87s
# elapsed 2749.9s | last  3.66s
# elapsed 2764.8s | last 14.84s
# elapsed 2768.2s | last  3.43s
# elapsed 2771.6s | last  3.41s
# elapsed 2775.1s | last  3.45s
# elapsed 2778.5s | last  3.46s
# elapsed 2782.1s | last  3.61s
# elapsed 2786.2s | last  4.07s
# elapsed 2789.6s | last  3.44s
# elapsed 2793.7s | last  4.08s
# elapsed 2796.8s | last  3.07s
# elapsed 2800.3s | last  3.53s
# elapsed 2804.3s | last  3.96s
# elapsed 2807.8s | last  3.55s
# elapsed 2822.7s | last 14.90s
# elapsed 2826.3s | last  3.53s
# elapsed 2830.1s | last  3.85s
# elapsed 2833.8s | last  3.67s
# elapsed 2837.4s | last  3.63s
# elapsed 2840.8s | last  3.41s
# elapsed 2844.7s | last  3.87s
# elapsed 2847.9s | last  3.14s
# elapsed 2862.5s | last 14.68s
# elapsed 2865.6s | last  3.04s
# elapsed 2868.6s | last  2.99s
# elapsed 2872.3s | last  3.70s
# elapsed 2887.2s | last 14.95s
# elapsed 2889.8s | last  2.53s
# elapsed 2892.8s | last  3.08s
# elapsed 2896.2s | last  3.33s
# elapsed 2900.4s | last  4.19s
# elapsed 2903.3s | last  2.98s
# elapsed 2906.5s | last  3.15s
# elapsed 2910.3s | last  3.76s
# elapsed 2913.6s | last  3.34s
# elapsed 2916.6s | last  3.04s
# elapsed 2919.7s | last  3.09s
# elapsed 2923.5s | last  3.73s
# elapsed 2926.8s | last  3.31s
# elapsed 2930.3s | last  3.54s
# elapsed 2933.9s | last  3.59s
# elapsed 2937.5s | last  3.64s
# elapsed 2940.8s | last  3.26s
# elapsed 2944.6s | last  3.79s
# elapsed 2947.7s | last  3.09s
# elapsed 2950.8s | last  3.14s
# elapsed 2954.1s | last  3.27s
# elapsed 2957.2s | last  3.08s
# elapsed 2960.7s | last  3.48s
# elapsed 2963.8s | last  3.09s
# elapsed 2968.0s | last  4.21s
# elapsed 2971.4s | last  3.45s
# elapsed 2986.4s | last 14.95s
# elapsed 2989.6s | last  3.18s
# elapsed 2992.9s | last  3.30s
# elapsed 2996.0s | last  3.16s
# elapsed 2999.0s | last  2.97s
# elapsed 3013.9s | last 14.87s
# elapsed 3028.8s | last 14.93s
# elapsed 3032.4s | last  3.59s
# elapsed 3035.5s | last  3.10s
# elapsed 3039.4s | last  3.93s
# elapsed 3042.5s | last  3.06s
# elapsed 3057.4s | last 14.87s
# elapsed 3061.4s | last  4.03s
# elapsed 3064.8s | last  3.41s
# elapsed 3068.2s | last  3.40s
# elapsed 3071.5s | last  3.27s
# elapsed 3074.7s | last  3.20s
# elapsed 3077.7s | last  3.06s
# elapsed 3080.9s | last  3.16s
# elapsed 3095.9s | last 14.96s
# elapsed 3098.8s | last  2.96s
# elapsed 3101.9s | last  3.09s
# elapsed 3116.7s | last 14.79s
# elapsed 3131.5s | last 14.84s
# elapsed 3134.5s | last  2.97s
# elapsed 3137.9s | last  3.39s
# elapsed 3152.8s | last 14.89s
# elapsed 3155.7s | last  2.88s
# elapsed 3158.7s | last  3.07s
# elapsed 3161.8s | last  3.10s
# elapsed 3164.8s | last  2.96s
# elapsed 3167.7s | last  2.94s
# elapsed 3170.8s | last  3.04s
# [██████████████████████████████████████████████████] 100.0%
# Done. Processed 631 posts in 3170.8s.
